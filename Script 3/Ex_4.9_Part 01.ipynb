# %% [markdown]
# # 01. Importing Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Importing Data Frame

# %%
df = pd.read_csv(r'/Users/sandeepti/Desktop/instacart Basket Analysis_python/02 Data/Original Data/customers.csv', index_col = False)

# %%
customers = pd.read_csv(r'/Users/sandeepti/Desktop/instacart Basket Analysis_python/02 Data/Original Data/customers.csv')

# %%
customers.head()
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
customers.shape
# Out:
# (206209, 10)

# %%
customers.describe()
# Out:
#              user_id            Age   n_dependants         income
# count  206209.000000  206209.000000  206209.000000  206209.000000
# mean   103105.000000      49.501646       1.499823   94632.852548
# std     59527.555167      18.480962       1.118433   42473.786988
# min         1.000000      18.000000       0.000000   25903.000000
# 25%     51553.000000      33.000000       0.000000   59874.000000
# 50%    103105.000000      49.000000       1.000000   93547.000000
# 75%    154657.000000      66.000000       3.000000  124244.000000
# max    206209.000000      81.000000       3.000000  593901.000000

# %% [markdown]
# # 03. Cleaning data

# %%
# Finding Missing values

customers.isnull().sum()
# Out:
# user_id             0
# First Name      11259
# Surnam              0
# Gender              0
# STATE               0
# Age                 0
# date_joined         0
# n_dependants        0
# fam_status          0
# income              0
# dtype: int64

# %%
# Finding NaN values 

df_nan = customers[customers['First Name'].isnull() == True]

# %%
df_nan
# Out:
#         user_id First Name    Surnam  Gender         STATE  Age date_joined  \
# 53        76659        NaN   Gilbert    Male      Colorado   26    1/1/2017
# 73        13738        NaN     Frost  Female     Louisiana   39    1/1/2017
# 82        89996        NaN    Dawson  Female        Oregon   52    1/1/2017
# 99        96166        NaN   Oconnor    Male      Oklahoma   51    1/1/2017
# 105       29778        NaN    Dawson  Female          Utah   63    1/1/2017
# ...         ...        ...       ...     ...           ...  ...         ...
# 206038   121317        NaN    Melton    Male  Pennsylvania   28   3/31/2020
# 206044   200799        NaN  Copeland  Female        Hawaii   52    4/1/2020
# 206090   167394        NaN     Frost  Female        Hawaii   61    4/1/2020
# 206162   187532        NaN     Floyd  Female    California   39    4/1/2020
# 206171   116898        NaN   Delgado  Female      Colorado   23    4/1/2020
#
#         n_dependants fam_status  income
# ...

# %%
# Cleaning the missing values

customers_clean = customers[customers['First Name'].isnull() == False]

# %%
customers_clean.shape
# Out:
# (194950, 10)

# %%
# Checking for Duplicate Values

df_dups = customers[customers.duplicated()]

# %%
df_dups
# Out:
# Empty DataFrame
# Columns: [user_id, First Name, Surnam, Gender, STATE, Age, date_joined, n_dependants, fam_status, income]
# Index: []

# %%
customers_clean.to_pickle(r'/Users/sandeepti/Desktop/instacart Basket Analysis_python/02 Data/Prepared Data/customers_clean.pkl')

# %% [markdown]
# # 04. Mearging Data

# %%
# Importing ords_prods_merge data

df = pd.read_pickle(r'/Users/sandeepti/Desktop/instacart Basket Analysis_python/02 Data/Prepared Data/ords_prods_merge.pkl')

# %%
ords_prods_merge = pd.read_pickle (r'/Users/sandeepti/Desktop/instacart Basket Analysis_python/02 Data/Prepared Data/ords_prods_merge.pkl')

# %%
df = pd.read_pickle (r'/Users/sandeepti/Desktop/instacart Basket Analysis_python/02 Data/Prepared Data/customers_clean.pkl')

# %%
customers_clean = pd.read_pickle (r'/Users/sandeepti/Desktop/instacart Basket Analysis_python/02 Data/Prepared Data/customers_clean.pkl')

# %%
df_ords_prods_cust_merge = customers_clean.merge(ords_prods_merge, on = 'user_id', indicator = False)

# %%
df_ords_prods_cust_merge.head()
# Out:
#    user_id First Name    Surnam  Gender     STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female  Missouri   48    1/1/2017
# 1    26711    Deborah  Esquivel  Female  Missouri   48    1/1/2017
# 2    26711    Deborah  Esquivel  Female  Missouri   48    1/1/2017
# 3    26711    Deborah  Esquivel  Female  Missouri   48    1/1/2017
# 4    26711    Deborah  Esquivel  Female  Missouri   48    1/1/2017
#
#    n_dependants fam_status  income  ...              product_name  aisle_id  \
# 0             3    married  165665  ...                      Soda      77.0
# 1             3    married  165665  ...                      Soda      77.0
# 2             3    married  165665  ...                      Soda      77.0
# 3             3    married  165665  ...  0% Greek Strained Yogurt     120.0
# 4             3    married  165665  ...  0% Greek Strained Yogurt     120.0
#
#    department_id  prices  max_order      loyalty_flag  max_price  \
# ...

# %%
df_ords_prods_cust_merge['_merge'].value_counts()
# Out:
# _merge
# both          30658154
# left_only       194950
# right_only           0
# Name: count, dtype: int64

# %%
df_ords_prods_cust_merge.shape
# Out:
# (30853104, 31)

# %%
ords_prods_cust_merge = df_ords_prods_cust_merge

# %%
ords_prods_cust_merge.describe()
# Out:
#             user_id           Age  n_dependants        income  Unnamed: 0_x  \
# count  3.085310e+07  3.085310e+07  3.085310e+07  3.085310e+07  3.085310e+07
# mean   1.029809e+05  4.947351e+01  1.501681e+00  9.942685e+04  1.710584e+06
# std    5.941851e+04  1.847859e+01  1.118468e+00  4.306213e+04  9.856628e+05
# min    1.000000e+00  1.800000e+01  0.000000e+00  2.590300e+04  0.000000e+00
# 25%    5.156600e+04  3.300000e+01  1.000000e+00  6.701800e+04  8.581750e+05
# 50%    1.026010e+05  4.900000e+01  2.000000e+00  9.659400e+04  1.708957e+06
# 75%    1.543850e+05  6.500000e+01  3.000000e+00  1.279160e+05  2.565831e+06
# max    2.062090e+05  8.100000e+01  3.000000e+00  5.939010e+05  3.421082e+06
#
#            order_id  order_number  orders_day_of_week  order_hour_of_day  \
# count  3.085310e+07  3.085310e+07        3.085310e+07       3.085310e+07
# mean   1.710708e+06  1.712015e+01        2.738255e+00       1.342609e+01
# ...

# %%
# Export data to pkl

ords_prods_cust_merge.to_pickle(r'/Users/sandeepti/Desktop/instacart Basket Analysis_python/02 Data/Prepared Data/ords_prods_cust_merge.pkl')
