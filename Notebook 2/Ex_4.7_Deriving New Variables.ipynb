# %% [markdown]
# # 01. Importing Libraries

# %%
import pandas as pd
import numpy as np
import os

# %%
# Define function

def add_num(x,y):
    sum = x + y
    return sum

# %%
# Run function

add_num(9,11)
# Out:
# 20

# %% [markdown]
# # 02. Importing Data Set

# %%
df = pd.read_pickle(r'/Users/sandeepti/Desktop/instacart Basket Analysis_python/02 Data/Prepared Data/orders_products_merged.pkl')

# %%
orders_products_merged = pd.read_pickle (r'/Users/sandeepti/Desktop/instacart Basket Analysis_python/02 Data/Prepared Data/orders_products_merged.pkl')

# %%
# importing data set in pickel format.

df = pd.read_pickle(r'/Users/sandeepti/Desktop/instacart Basket Analysis_python/02 Data/Prepared Data/orders_products_combined.pkl')

# %%
df_orders_products_combined = pd.read_pickle(r'/Users/sandeepti/Desktop/instacart Basket Analysis_python/02 Data/Prepared Data/orders_products_combined.pkl')

# %%
df = pd.read_csv(r'/Users/sandeepti/Desktop/instacart Basket Analysis_python/02 Data/Prepared Data/products_checked.csv',index_col = False)

# %%
df_prods_checked =  pd.read_csv(r'/Users/sandeepti/Desktop/instacart Basket Analysis_python/02 Data/Prepared Data/products_checked.csv')

# %%
# Merging data frames df_orders_products_combined and Df_prods_checked

df_orders_products_merged = df_orders_products_combined.merge(df_prods_checked, on = 'product_id', indicator = False, how = 'outer')

# %%
# Creating subset of the dataframe for 1 Million rows

df = orders_products_merged[:1000000]

# %% [markdown]
# # 03. If Statements

# %%
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# /var/folders/gv/sm1b476s1zz2r143g9h9qgj40000gq/T/ipykernel_11162/2848743372.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
# Create a subset

df = orders_products_merged[:1000000]

# %%
df.shape
# Out:
# (1000000, 16)

# %%
df['price_range'].value_counts(dropna = False)
# Out:
# price_range
# Mid-range product    581197
# Low-range product    212594
# Not enough data      206209
# Name: count, dtype: int64

# %%
df['prices'].max()
# Out:
# 14.0

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# /var/folders/gv/sm1b476s1zz2r143g9h9qgj40000gq/T/ipykernel_11162/1169838859.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df['price_range_loc'].value_counts(dropna = False)
# Out:
# price_range_loc
# Mid-range product    581197
# Low-range product    212594
# NaN                  206209
# Name: count, dtype: int64

# %%
orders_products_merged.loc[orders_products_merged['prices'] > 15, 'price_range_loc']= 'High-range product'

# %%
orders_products_merged.loc[(orders_products_merged['prices'] <= 15) & (orders_products_merged['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
orders_products_merged.loc[orders_products_merged['prices'] <= 5, 'price_range_loc'] = 'low-range product'

# %%
orders_products_merged['price_range_loc'].value_counts(dropna = False)
# Out:
# price_range_loc
# Mid-range product     21860868
# low-range product     10126324
# High-range product      417678
# NaN                     236409
# Name: count, dtype: int64

# %% [markdown]
# # 04. If Statments with For-Loops

# %%
# This is without using for loops

print("My age is 30")
# Out:
# My age is 30

# %%
print ("My age is 31")
# Out:
# My age is 31

# %%
# Using for loop

for x in range (30,45):
    print("My age is %d" % (x))
# Out:
# My age is 30
# My age is 31
# My age is 32
# My age is 33
# My age is 34
# My age is 35
# My age is 36
# My age is 37
# My age is 38
# My age is 39
# My age is 40
# My age is 41
# My age is 42
# My age is 43
# My age is 44

# %%
orders_products_merged.head()
# Out:
#    Unnamed: 0_x   order_id  user_id  order_number  orders_day_of_week  \
# 0           0.0  2539329.0      1.0           1.0                 2.0
# 1           1.0  2398795.0      1.0           2.0                 3.0
# 2           2.0   473747.0      1.0           3.0                 3.0
# 3           3.0  2254736.0      1.0           4.0                 4.0
# 4           4.0   431534.0      1.0           5.0                 4.0
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                8.0                     NaN       196.0                1.0
# 1                7.0                    15.0       196.0                1.0
# 2               12.0                    21.0       196.0                1.0
# 3                7.0                    29.0       196.0                1.0
# 4               15.0                    28.0       196.0                1.0
#
#    reordered _merge  Unnamed: 0_y product_name  aisle_id  department_id  \
# ...

# %%
orders_products_merged['orders_day_of_week'].value_counts(dropna = False)
# Out:
# orders_day_of_week
# 0.0    6252941
# 1.0    5696724
# 6.0    4530304
# 2.0    4243173
# 5.0    4236989
# 3.0    3868747
# 4.0    3812390
# NaN         11
# Name: count, dtype: int64

# %%
result = []

for value in orders_products_merged["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
orders_products_merged['busiest_day']= result

# %%
orders_products_merged['busiest_day'].value_counts(dropna = False)
# Out:
# busiest_day
# Regularly busy    22575948
# Busiest day        6252941
# Least busy         3812390
# Name: count, dtype: int64

# %%
# Creating busiest_days 


result = []

for value in orders_products_merged["orders_day_of_week"]:
  if value == 1:
    result.append("Busiest days")

# %%
result
# Out:
# ['Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
# ...

# %%
# Creating slowest_days


result = []

for value in orders_products_merged["orders_day_of_week"]:
  if value == 5:
    result.append("slowest days")

# %%
result
# Out:
# ['slowest days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
# ...

# %%
# Create a new column containing these labels called “busiest_period_of_day.”

result = []

for value in orders_products_merged["order_hour_of_day"]:
  if value == 15:
    result.append("Most orders")
  elif value == 8:
    result.append("Average orders")
  else:
    result.append("Fewest orders")

# %%
result
# Out:
# ['Average orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Most orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Average orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Average orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Average orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Most orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
# ...

# %%
orders_products_merged['Most orders']= result

# %%
orders_products_merged['Most orders'].value_counts(dropna = False)
# Out:
# Most orders
# Fewest orders     28229318
# Most orders        2682090
# Average orders     1729871
# Name: count, dtype: int64

# %%
# Creating by hour “Most orders,” “Average orders,” and “Fewest orders.” 

result = []

for value in orders_products_merged["order_hour_of_day"]:
  if value == 15:
    result.append("Most orders")

# %%
result
# Out:
# ['Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
# ...

# %%
result = []

for value in orders_products_merged["order_hour_of_day"]:
  if value == 8:
    result.append("Average orders")

# %%
result
# Out:
# ['Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
# ...

# %%
result = []

for value in orders_products_merged["order_hour_of_day"]:
  if value == 6:
    result.append("Fewest orders")

# %%
result
# Out:
# ['Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
# ...

# %%
# Export data to pkl

orders_products_merged.to_pickle(r'/Users/sandeepti/Desktop/instacart Basket Analysis_python/02 Data/Prepared Data/orders_products_merged.pkl')

# %%
ords_prods_merge.to_pickle(r'/Users/sandeepti/Desktop/instacart Basket Analysis_python/02 Data/Prepared Data/ords_prods_merge.pkl')
